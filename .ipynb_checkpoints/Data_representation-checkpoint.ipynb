# %% [markdown]
# # 5 Graphics howto

# %% [markdown]
# This is my first playbook. Show the steps to do some data work.
#
#
# ## Load Data

# %%
import pandas as pd
from numpy import genfromtxt
df = pd.read_csv('sources/cars.csv')

df
# Out:
#                                    Car   MPG  Cylinders  Displacement  \
# 0            Chevrolet Chevelle Malibu  18.0          8         307.0
# 1                    Buick Skylark 320  15.0          8         350.0
# 2                   Plymouth Satellite  18.0          8         318.0
# 3                        AMC Rebel SST  16.0          8         304.0
# 4                          Ford Torino  17.0          8         302.0
# 5                     Ford Galaxie 500  15.0          8         429.0
# 6                     Chevrolet Impala  14.0          8         454.0
# 7                    Plymouth Fury iii  14.0          8         440.0
# 8                     Pontiac Catalina  14.0          8         455.0
# 9                   AMC Ambassador DPL  15.0          8         390.0
# 10                Citroen DS-21 Pallas   0.0          4         133.0
# 11    Chevrolet Chevelle Concours (sw)   0.0          8         350.0
# 12                    Ford Torino (sw)   0.0          8         351.0
# 13             Plymouth Satellite (sw)   0.0          8         383.0
# 14                  AMC Rebel SST (sw)   0.0          8         360.0
# 15                 Dodge Challenger SE  15.0          8         383.0
# 16                  Plymouth 'Cuda 340  14.0          8         340.0
# 17               Ford Mustang Boss 302   0.0          8         302.0
# 18               Chevrolet Monte Carlo  15.0          8         400.0
# 19             Buick Estate Wagon (sw)  14.0          8         455.0
# 20              Toyota Corolla Mark ii  24.0          4         113.0
# 21                     Plymouth Duster  22.0          6         198.0
# 22                          AMC Hornet  18.0          6         199.0
# 23                       Ford Maverick  21.0          6         200.0
# 24                        Datsun PL510  27.0          4          97.0
# 25        Volkswagen 1131 Deluxe Sedan  26.0          4          97.0
# 26                         Peugeot 504  25.0          4         110.0
# 27                         Audi 100 LS  24.0          4         107.0
# 28                            Saab 99e  25.0          4         104.0
# 29                            BMW 2002  26.0          4         121.0
# ..                                 ...   ...        ...           ...
# 376           Chevrolet Cavalier Wagon  27.0          4         112.0
# 377          Chevrolet Cavalier 2-door  34.0          4         112.0
# 378         Pontiac J2000 SE Hatchback  31.0          4         112.0
# 379                     Dodge Aries SE  29.0          4         135.0
# 380                    Pontiac Phoenix  27.0          4         151.0
# 381               Ford Fairmont Futura  24.0          4         140.0
# 382                     AMC Concord DL  23.0          4         151.0
# 383                Volkswagen Rabbit l  36.0          4         105.0
# 384                 Mazda GLC Custom l  37.0          4          91.0
# 385                   Mazda GLC Custom  31.0          4          91.0
# 386             Plymouth Horizon Miser  38.0          4         105.0
# 387                     Mercury Lynx l  36.0          4          98.0
# 388                   Nissan Stanza XE  36.0          4         120.0
# 389                       Honda Accord  36.0          4         107.0
# 390                     Toyota Corolla  34.0          4         108.0
# 391                        Honda Civic  38.0          4          91.0
# 392                 Honda Civic (auto)  32.0          4          91.0
# 393                      Datsun 310 GX  38.0          4          91.0
# 395        85.0  3015.0          17.0     82      US
# 396        92.0  2585.0          14.5     82      US
# 397       112.0  2835.0          14.7     82      US
# 398        96.0  2665.0          13.9     82   Japan
# 399        84.0  2370.0          13.0     82      US
# 400        90.0  2950.0          17.3     82      US
# 401        86.0  2790.0          15.6     82      US
# 402        52.0  2130.0          24.6     82  Europe
# 403        84.0  2295.0          11.6     82      US
# 404        79.0  2625.0          18.6     82      US
# 405        82.0  2720.0          19.4     82      US
#
# [406 rows x 9 columns]

# %%
df.describe()
# Out:
#               MPG   Cylinders  Displacement  Horsepower       Weight  \
# count  406.000000  406.000000    406.000000  406.000000   406.000000
# mean    23.051232    5.475369    194.779557  103.529557  2979.413793
# std      8.401777    1.712160    104.922458   40.520659   847.004328
# min      0.000000    3.000000     68.000000    0.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2226.500000
# 50%     22.350000    4.000000    151.000000   93.500000  2822.500000
# 75%     29.000000    8.000000    302.000000  129.000000  3618.250000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        Acceleration       Model
# count    406.000000  406.000000
# mean      15.519704   75.921182
# std        2.803359    3.748737
# min        8.000000   70.000000
# 25%       13.700000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %% [markdown]
# ## Use graphsfrom from pyplot

# %%
import pylab as p
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

df = pd.read_csv('sources/cars.csv')
df.Origin.value_counts()
CountStatus = df.Origin.value_counts()
CountStatus.plot.barh()
plt.savefig('img/cars-counts.png')

# %% [markdown]
# ![title](img/cars-counts.png)

# %% [markdown]
# ## Use SQL commands in a dataframe
#
# You can use SQL commands to handle a Data Frame wirh the the pandasql libray.

# %%
# !pip install pandasql plotly 1>/dev/null

# %%
import pandasql as pdsql
import pandas as pd

df = pd.read_csv('sources/cars.csv')


pysql = lambda q: pdsql.sqldf(q, globals())
df1 = pysql("SELECT AVG(Horsepower) AS Horsepower,  AVG(Weight) AS Weight,Weight/Horsepower AS Ratio,Origin  FROM df GROUP BY Origin ORDER BY Ratio ")
df1 

#df1.plot.barh()
# Out:
#    Horsepower       Weight      Ratio  Origin
# 0   79.835443  2221.227848  27.760417   Japan
# 1  118.011811  3372.700787  33.170732      US
# 2   78.780822  2431.493151  40.961538  Europe

# %%
import matplotlib.pyplot as plt
import matplotlib

import plotly
import plotly.plotly as pp 
import plotly.offline as py
import plotly.graph_objs as go

py.init_notebook_mode(connected=True)

fig = pp.get_figure('https://plot.ly/~jaimevalero78/2', raw=True)

iplot(fig,validate=False)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="23d17aa3-f52b-4b7d-af02-d282b9d43b2e" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '23d17aa3-f52b-4b7d-af02-d282b9d43b2e',
", "Saab 99e", "BMW 2002", "AMC Gremlin", "Ford F250", "Chevy C20", "Dodge D200", "Hi 1200D", "Datsun PL510", "Chevrolet Vega 2300", "Toyota Corolla", "Ford Pinto", "Volkswagen Super Beetle 117", "AMC Gremlin", "Plymouth Satellite Custom", "Chevrolet Chevelle Malibu", "Ford Torino 500", "AMC Matador", "Chevrolet Impala", "Pontiac Catalina Brougham", "Ford Galaxie 500", "Plymouth Fury iii", "Dodge Monaco (sw)", "Ford Country Squire (sw)", "Pontiac Safari (sw)", "AMC Hornet Sportabout (sw)", "Chevrolet Vega (sw)", "Pontiac Firebird", "Ford Mustang", "Mercury Capri 2000", "Opel 1900", "Peugeot 304", "Fiat 124B", "Toyota Corolla 1200", "Datsun 1200", "Volkswagen Model 111", "Plymouth Cricket", "Toyota Corolla Hardtop", "Dodge Colt Hardtop", "Volkswagen Type 3", "Chevrolet Vega", "Ford Pinto Runabout", "Chevrolet Impala", "Pontiac Catalina", "Plymouth Fury III", "Ford Galaxie 500", "AMC Ambassador SST", "Mercury Marquis", "Buick LeSabr ...

# %% [markdown]
# ![title](sources/Ratio.png)

# %% [markdown]
# In the last graphic, we can see we have empty data.
# Lets fill 0's with the median data, and plot it again.
# This time, using matplotlib.

# %%
import matplotlib.pyplot as plt
import pylab as p
import pandas as pd
import numpy as np
import matplotlib

df = pd.read_csv('sources/cars.csv')

# Replace 0s with median value
df['Horsepower']=df['Horsepower'].replace(0,df['Horsepower'].mean())

X_ = 'Horsepower'
Y_ = 'Weight'
CLASS_ = 'Origin'

fig, ax = plt.subplots()
lista_tipos = df[CLASS_].sort_values().unique()

i=0
# Iterate trough list
for tipo in lista_tipos :
    estetipo = df[CLASS_] == tipo
    subdf = df[estetipo]

    x = subdf[X_]
    y = subdf[Y_]
    c = subdf[CLASS_] 
    ax.scatter(x=x, y=y,  label = tipo  )
    i+=1

ax.set(title='Horse power / Weight Ratio', ylabel = Y_ , xlabel = X_ )

plt.legend()
    

plt.show()

# %%
import matplotlib.pyplot as plt
import pylab as p
import pandas as pd
import numpy as np
import matplotlib

df = pd.read_csv('sources/cars.csv')

# Replace 0s with median value
df['Horsepower']=df['Horsepower'].replace(0,df['Horsepower'].mean())
df['MPG']=df['MPG'].replace(0,df['MPG'].mean())

X_ = 'MPG'
Y_ = 'Displacement'
CLASS_ = 'Cylinders'

fig, ax = plt.subplots()
lista_tipos = df[CLASS_].sort_values().unique()


i=0
# Iterate trough list
for tipo in lista_tipos :
    estetipo = df[CLASS_] == tipo
    subdf = df[estetipo]

    x = subdf[X_]
    y = subdf[Y_]
    c = subdf[CLASS_] 
    ax.scatter(x=x, y=y,  label = tipo  )
    i+=1

ax.set(title='MPG / Displacement Ratio', ylabel = Y_ , xlabel = X_ )

plt.legend()
    

plt.show()
